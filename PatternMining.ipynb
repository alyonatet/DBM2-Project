# %% [markdown]
# ## Setup

# %% [markdown]
# ### Contains useful pattern mining tools

# %%
# %pip install mlxtend
# Out:
# Requirement already satisfied: mlxtend in c:\users\fiona eguare\appdata\local\programs\python\python39\lib\site-packages (0.23.0)Note: you may need to restart the kernel to use updated packages.
#
# Requirement already satisfied: scikit-learn>=1.0.2 in c:\users\fiona eguare\appdata\local\programs\python\python39\lib\site-packages (from mlxtend) (1.3.2)
# Requirement already satisfied: pandas>=0.24.2 in c:\users\fiona eguare\appdata\local\programs\python\python39\lib\site-packages (from mlxtend) (2.1.2)
# Requirement already satisfied: scipy>=1.2.1 in c:\users\fiona eguare\appdata\local\programs\python\python39\lib\site-packages (from mlxtend) (1.11.4)
# Requirement already satisfied: numpy>=1.16.2 in c:\users\fiona eguare\appdata\local\programs\python\python39\lib\site-packages (from mlxtend) (1.26.1)
# Requirement already satisfied: matplotlib>=3.0.0 in c:\users\fiona eguare\appdata\local\programs\python\python39\lib\site-packages (from mlxtend) (3.8.2)
# Requirement already satisfied: joblib>=0.13.2 in c:\users\fiona eguare\appdata\local\programs\python\python39\lib\site-packages (from mlxtend) (1.3.2)
# Requirement already satisfied: pillow>=8 in c:\users\fiona eguare\appdata\local\programs\python\python39\lib\site-packages (from matplotlib>=3.0.0->mlxtend) (10.0.1)
# Requirement already satisfied: pyparsing>=2.3.1 in c:\users\fiona eguare\appdata\local\programs\python\python39\lib\site-packages (from matplotlib>=3.0.0->mlxtend) (3.1.1)
# Requirement already satisfied: importlib-resources>=3.2.0 in c:\users\fiona eguare\appdata\local\programs\python\python39\lib\site-packages (from matplotlib>=3.0.0->mlxtend) (6.1.1)
# Requirement already satisfied: contourpy>=1.0.1 in c:\users\fiona eguare\appdata\local\programs\python\python39\lib\site-packages (from matplotlib>=3.0.0->mlxtend) (1.2.0)
# Requirement already satisfied: fonttools>=4.22.0 in c:\users\fiona eguare\appdata\local\programs\python\python39\lib\site-packages (from matplotlib>=3.0.0->mlxtend) (4.45.1)
# Requirement already satisfied: python-dateutil>=2.7 in c:\users\fiona eguare\appdata\local\programs\python\python39\lib\site-packages (from matplotlib>=3.0.0->mlxtend) (2.8.2)
# Requirement already satisfied: cycler>=0.10 in c:\users\fiona eguare\appdata\local\programs\python\python39\lib\site-packages (from matplotlib>=3.0.0->mlxtend) (0.12.1)
# Requirement already satisfied: packaging>=20.0 in c:\users\fiona eguare\appdata\local\programs\python\python39\lib\site-packages (from matplotlib>=3.0.0->mlxtend) (23.2)
# Requirement already satisfied: kiwisolver>=1.3.1 in c:\users\fiona eguare\appdata\local\programs\python\python39\lib\site-packages (from matplotlib>=3.0.0->mlxtend) (1.4.5)
# Requirement already satisfied: zipp>=3.1.0 in c:\users\fiona eguare\appdata\local\programs\python\python39\lib\site-packages (from importlib-resources>=3.2.0->matplotlib>=3.0.0->mlxtend) (3.17.0)
# Requirement already satisfied: pytz>=2020.1 in c:\users\fiona eguare\appdata\local\programs\python\python39\lib\site-packages (from pandas>=0.24.2->mlxtend) (2023.3.post1)
# Requirement already satisfied: tzdata>=2022.1 in c:\users\fiona eguare\appdata\local\programs\python\python39\lib\site-packages (from pandas>=0.24.2->mlxtend) (2023.3)
# Requirement already satisfied: six>=1.5 in c:\users\fiona eguare\appdata\local\programs\python\python39\lib\site-packages (from python-dateutil>=2.7->matplotlib>=3.0.0->mlxtend) (1.16.0)
# Requirement already satisfied: threadpoolctl>=2.0.0 in c:\users\fiona eguare\appdata\local\programs\python\python39\lib\site-packages (from scikit-learn>=1.0.2->mlxtend) (3.2.0)
# WARNING: You are using pip version 21.1.1; however, version 23.3.1 is available.
# You should consider upgrading via the 'c:\Users\Fiona Eguare\AppData\Local\Programs\Python\Python39\python.exe -m pip install --upgrade pip' command.

# %% [markdown]
# ### Useful imports
# Below are the imports that were useful in the cleaning & pre-processing, and the pattern mining

# %%
import pandas as pd
import numpy as np
import time
import tracemalloc
from mlxtend.frequent_patterns import apriori
from mlxtend.frequent_patterns import fpgrowth
from mlxtend.frequent_patterns import association_rules

# %% [markdown]
# ### Set dataframe default to not truncate the values

# %%
pd.set_option("display.max_colwidth", None)

# %% [markdown]
# ## Cleaning & Preprocessing (general)
# We started the cleaning the data by dropping the unneccesary columns reduce the dimensions of the dataset. The columns that were dropped didn't contribute to any improvements in regards of the classification problem so we decided to drop them. We started by converting the strings to floats by encoding them, but we then decided to drop them anyways since they didn't contribute to the algorithm. We also noticed some inconsistincies, for example some values were just missing, others conained questionmarks (?) and others said 'NaN'. We decided to replace all of the missing values with 'NaN' so it would be easier to remove all of them later.
#
# Furthermore, we replaced the mode (Minor/Major) with the float values 0.0 and 1.0, so that all of the feature data is stored as the same type (float64). We also realised that there are five rows that only contain NaN values, so we removed those as well.
#
# Lastly we noticed that the column 'tempo' for some reason contained lots of missing values, so we dropped that as well.

# %%
# Fetch Data
data = pd.read_csv('music_dataset.csv', header='infer')

# Drop unnecessary columns
columns_drop = ['instance_id', 'track_name', 'key', 'obtained_date', 'artist_name']  # popularity #duration_ms
rows_drop = ['Rap', 'Alternative']

# Drop rows based on conditions
data = data[~data['music_genre'].isin(rows_drop)]
data = data.drop(columns=columns_drop)
print(data.head(10))

# Replace '?' with NaN
data = data.applymap(lambda cell: np.NaN if str(cell) == "?" else cell)

# Replace missing values with NaN
data = data.fillna(np.NaN)

# Replace mode with binary numbers
data['mode'] = data['mode'].replace({'Minor': 0.0, 'Major': 1.0})

# Count missing values for every column in our dataset
NaN_values = data.isna().sum()
print("Missing values per column:")
print(NaN_values)

# Check to see if they are all on the same row
NaN_rows = data[data.isna().all(axis=1)]
print(NaN_rows)             

# Drop rows with all NaN values
data = data.dropna(how='all')

# Lots of missing values, drop this column
data = data.drop(columns='tempo')
# Out:
#    popularity  acousticness  danceability  duration_ms  energy  \
# 0        27.0       0.00468         0.652         -1.0   0.941
# 1        31.0       0.01270         0.622     218293.0   0.890
# 2        28.0       0.00306         0.620     215613.0   0.755
# 3        34.0       0.02540         0.774     166875.0   0.700
# 4        32.0       0.00465         0.638     222369.0   0.587
# 5        47.0       0.00523         0.755     519468.0   0.731
# 6        46.0       0.02890         0.572     214408.0   0.803
# 7        43.0       0.02970         0.809     416132.0   0.706
# 8        39.0       0.00299         0.509     292800.0   0.921
# 9        22.0       0.00934         0.578     204800.0   0.731
#
#    instrumentalness  liveness  loudness   mode  speechiness  \
# 0          0.792000    0.1150    -5.201  Minor       0.0748
# 1          0.950000    0.1240    -7.043  Minor       0.0300
# 2          0.011800    0.5340    -4.617  Major       0.0345
# 3          0.002530    0.1570    -4.498  Major       0.2390
# 4          0.909000    0.1570    -6.266  Major       0.0413
# 5          0.854000    0.2160   -10.517  Minor       0.0412
# 6          0.000008    0.1060    -4.294  Major       0.3510
# 7          0.903000    0.0635    -9.339  Minor       0.0484
# 8          0.000276    0.1780    -3.175  Minor       0.2680
# 9          0.011200    0.1110    -7.091  Minor       0.1730
#
#                 tempo  valence music_genre
# 0             100.889    0.759  Electronic
# 1  115.00200000000001    0.531  Electronic
# 2             127.994    0.333  Electronic
# 3             128.014    0.270  Electronic
# 4             145.036    0.323  Electronic
# 5                   ?    0.614  Electronic
# 6             149.995    0.230  Electronic
# 7             120.008    0.761  Electronic
# 8  149.94799999999998    0.273  Electronic
# 9             139.933    0.203  Electronic
# C:\Users\Fiona Eguare\AppData\Local\Temp\ipykernel_16480\4054054948.py:14: FutureWarning: DataFrame.applymap has been deprecated. Use DataFrame.map instead.
#   data = data.applymap(lambda cell: np.NaN if str(cell) == "?" else cell)
# Missing values per column:
# popularity             5
# acousticness           5
# danceability           5
# duration_ms            5
# energy                 5
# instrumentalness       5
# liveness               5
# loudness               5
# mode                   5
# speechiness            5
# tempo               3984
# valence                5
# music_genre            5
# dtype: int64
#        popularity  acousticness  danceability  duration_ms  energy  \
# 10000         NaN           NaN           NaN          NaN     NaN
# 10001         NaN           NaN           NaN          NaN     NaN
# 10002         NaN           NaN           NaN          NaN     NaN
# 10003         NaN           NaN           NaN          NaN     NaN
# 10004         NaN           NaN           NaN          NaN     NaN
#
#        instrumentalness  liveness  loudness  mode  speechiness tempo  valence  \
# 10000               NaN       NaN       NaN   NaN          NaN   NaN      NaN
# 10001               NaN       NaN       NaN   NaN          NaN   NaN      NaN
# 10002               NaN       NaN       NaN   NaN          NaN   NaN      NaN
# 10003               NaN       NaN       NaN   NaN          NaN   NaN      NaN
# 10004               NaN       NaN       NaN   NaN          NaN   NaN      NaN
#
#       music_genre
# 10000         NaN
# 10001         NaN
# 10002         NaN
# 10003         NaN
# 10004         NaN

# %% [markdown]
# ## Pattern Mining

# %% [markdown]
# ### Select the data to be mined (all numeric data)

# %%
pm_all_data = data.drop(columns='music_genre')
pm_all_data
# Out:
#        popularity  acousticness  danceability  duration_ms  energy  \
# 0            27.0       0.00468         0.652         -1.0   0.941
# 1            31.0       0.01270         0.622     218293.0   0.890
# 2            28.0       0.00306         0.620     215613.0   0.755
# 3            34.0       0.02540         0.774     166875.0   0.700
# 4            32.0       0.00465         0.638     222369.0   0.587
# ...           ...           ...           ...          ...     ...
# 50000        59.0       0.03340         0.913         -1.0   0.574
# 50001        72.0       0.15700         0.709     251860.0   0.362
# 50002        51.0       0.00597         0.693     189483.0   0.763
# 50003        65.0       0.08310         0.782     262773.0   0.472
# 50004        67.0       0.10200         0.862     267267.0   0.642
#
#        instrumentalness  liveness  loudness  mode  speechiness  valence
# 0               0.79200     0.115    -5.201   0.0       0.0748    0.759
# 1               0.95000     0.124    -7.043   0.0       0.0300    0.531
# 2               0.01180     0.534    -4.617   1.0       0.0345    0.333
# 3               0.00253     0.157    -4.498   1.0       0.2390    0.270
# 4               0.90900     0.157    -6.266   1.0       0.0413    0.323
# ...                 ...       ...       ...   ...          ...      ...
# 50000           0.00000     0.119    -7.022   1.0       0.2980    0.330
# 50001           0.00000     0.109    -9.814   1.0       0.0550    0.113
# 50002           0.00000     0.143    -5.443   1.0       0.1460    0.395
# 50003           0.00000     0.106    -5.016   0.0       0.0441    0.354
# 50004           0.00000     0.272   -13.652   0.0       0.1010    0.765
#
# [40000 rows x 11 columns]

# %% [markdown]
# ### Functions to normalise
# Can be called to normalise the given data (df) by the normalisation method specified by normType (min-max -> 'm', z-score -> 'z')

# %%
def dfNorm(df, normType):
  for (column_name, column) in df.transpose().iterrows():
    if normType == 'm':
      mmNormalise(df, column_name)
    elif normType == 'z':
      zNormalise(df, column_name)
  return df

# Min-Max normalisation function
def mmNormalise(df, name):
  df[name] = ((df[name] - df[name].min()) / (df[name].max() - df[name].min())) - 0.5 # -0.5 to centre it around 0, to accomodate z score in discretisation function. [-0.5,0.5 normalised]

# Z-Score normalisation function
def zNormalise(df, name):
  df[name] = (df[name] - df[name].mean()) / df[name].std()

# %% [markdown]
# ### Functions to discretise
# Can be called to create and populate low and high collums for each arrtribute

# %%
def stratifyData(df):
  for (column_name, column) in df.transpose().iterrows():

    new_column_name = 'Low ' + column_name
    df[new_column_name] = df[column_name].apply(isLow)

    new_column_name = 'High ' + column_name
    df[new_column_name] = df[column_name].apply(isHigh)

    df = df.drop(labels=column_name, axis=1)

  return df

# To fill the 'low...' colums
def isLow(val):
  return True if float(val) < 0 else False

# To fill the 'high...' colums
def isHigh(val):
  return True if float(val) >= 0 else False

# %% [markdown]
# ### Functions to mine frequent patterns using above functions
# - getFreq can be called to get a data frame containing all frequent itemsets with a minimum support of minSup, using the algorithm specified by pmType (A.priori -> 'a', FP-Growth -> 'f').
# - getMore can be called to get a a datafram containing more interestingness data (association rules) for the frequent patterns given, with a default minimum confidence of 0.7.
# - pMine takes the dataframe of data to be mined (df), the type of normalisation desired (nType) and the minimum support desired (minSup) as input, and displays the resluting frequent patterns & their association rules.

# %%
def getFreq(df, minSup, pmType):
  if pmType == 'a':
    return apriori(df, use_colnames=True, min_support=minSup)
  elif pmType == 'f':
    return fpgrowth(df, use_colnames=True, min_support=minSup)

def getMore(freq):
  return association_rules(freq)[['antecedents', 'consequents', 'antecedent support', 'consequent support',	'support', 'confidence', 'lift']]

# %%
def pMine(df, nType, minSup):
  # normalise the data
  ndf = dfNorm(df, nType)

  # stratify the data
  ndf = stratifyData(ndf)
  display(ndf)

  # get list of frequent patterns with Minimum Support = minSup and display
  freq = getFreq(ndf, minSup, 'f')
  display(freq)

  # get more pattern interestingness metrics for freq patterns (with Minimum Confidence 0.7) and display
  more = getMore(freq)
  display(more)

# %% [markdown]
# ### Example Frequent Pattern mining outputs
# The first table show the dicretised form of the data to be mined, the second shows the frequent patterns mined, and the third shows some interestingness data relating to the frequent patterns.

# %%
pMine(pm_all_data.copy(), 'm', 0.7)
# Out:
#        Low popularity  High popularity  Low acousticness  High acousticness  \
# 0                True            False              True              False
# 1                True            False              True              False
# 2                True            False              True              False
# 3                True            False              True              False
# 4                True            False              True              False
# ...               ...              ...               ...                ...
# 50000           False             True              True              False
# 50001           False             True              True              False
# 50002           False             True              True              False
# 50003           False             True              True              False
# 50004           False             True              True              False
#
#        Low danceability  High danceability  Low duration_ms  High duration_ms  \
# 0                 False               True             True             False
# 1                 False               True             True             False
# 2                 False               True             True             False
# 3                 False               True             True             False
# 4                 False               True             True             False
# ...                 ...                ...              ...               ...
# 50000             False               True             True             False
# 50001             False               True             True             False
# 50002             False               True             True             False
# 50003             False               True             True             False
# 50004             False               True             True             False
#
#        Low energy  High energy  ...  Low liveness  High liveness  \
# 0           False         True  ...          True          False
# 1           False         True  ...          True          False
# 2           False         True  ...         False           True
# 3           False         True  ...          True          False
# 4           False         True  ...          True          False
# ...           ...          ...  ...           ...            ...
# 50000       False         True  ...          True          False
# 50001        True        False  ...          True          False
# 50002       False         True  ...          True          False
# 50003        True        False  ...          True          False
# 50004       False         True  ...          True          False
#
#        Low loudness  High loudness  Low mode  High mode  Low speechiness  \
# 0             False           True      True      False             True
# 1             False           True      True      False             True
# 2             False           True     False       True             True
# 3             False           True     False       True             True
# 4             False           True     False       True             True
# ...             ...            ...       ...        ...              ...
# 50000         False           True     False       True             True
# 50001         False           True     False       True             True
# 50002         False           True     False       True             True
# 50003         False           True      True      False             True
# 50004         False           True      True      False             True
#
#        High speechiness  Low valence  High valence
# 0                 False        False          True
# 1                 False        False          True
# 2                 False         True         False
# 3                 False         True         False
# 4                 False         True         False
# ...                 ...          ...           ...
# 50000             False         True         False
# 50001             False         True         False
# 50002             False         True         False
# 50003             False         True         False
# 50004             False        False          True
#
# [40000 rows x 22 columns]
#      support  \
# 0   0.999875
# 1   0.993800
# 2   0.942150
# 3   0.924450
# 4   0.766025
# 5   0.993675
# 6   0.942050
# 7   0.936875
# 8   0.936775
# 9   0.924350
# 10  0.918525
# 11  0.869225
# 12  0.918425
# 13  0.869125
# 14  0.864150
# 15  0.864050
# 16  0.765925
# 17  0.760025
# 18  0.747075
# 19  0.718300
# 20  0.759925
# 21  0.747000
# 22  0.741350
# 23  0.741275
# 24  0.718225
# 25  0.713225
# 26  0.701225
# 27  0.713150
# 28  0.701150
#
#                                                                    itemsets
# 0                                                         (Low duration_ms)
# 1                                                         (Low speechiness)
# 2                                                            (Low liveness)
# 3                                                           (High loudness)
# 4                                                    (Low instrumentalness)
# 5                                        (Low duration_ms, Low speechiness)
# 6                                           (Low duration_ms, Low liveness)
# 7                                           (Low liveness, Low speechiness)
# 8                          (Low duration_ms, Low liveness, Low speechiness)
# 9                                          (Low duration_ms, High loudness)
# 10                                         (High loudness, Low speechiness)
# 11                                            (High loudness, Low liveness)
# 12                        (Low duration_ms, High loudness, Low speechiness)
# 13                           (Low duration_ms, High loudness, Low liveness)
# 14                           (High loudness, Low liveness, Low speechiness)
# 15          (Low duration_ms, High loudness, Low liveness, Low speechiness)
# 16                                  (Low duration_ms, Low instrumentalness)
# 17                                  (Low instrumentalness, Low speechiness)
# 18                                    (High loudness, Low instrumentalness)
# 19                                     (Low instrumentalness, Low liveness)
# 20                 (Low duration_ms, Low instrumentalness, Low speechiness)
# 21                   (Low duration_ms, High loudness, Low instrumentalness)
# 22                   (High loudness, Low instrumentalness, Low speechiness)
# 23  (Low duration_ms, High loudness, Low instrumentalness, Low speechiness)
# 24                    (Low duration_ms, Low instrumentalness, Low liveness)
# 25                    (Low instrumentalness, Low liveness, Low speechiness)
# 26                      (High loudness, Low instrumentalness, Low liveness)
# 27   (Low duration_ms, Low instrumentalness, Low liveness, Low speechiness)
# 28     (Low duration_ms, High loudness, Low instrumentalness, Low liveness)
#                                  antecedents  \
# 0                          (Low duration_ms)
# 1                          (Low speechiness)
# 2                          (Low duration_ms)
# 3                             (Low liveness)
# 4                             (Low liveness)
# ..                                       ...
# 100  (Low duration_ms, Low instrumentalness)
# 101    (High loudness, Low instrumentalness)
# 102            (High loudness, Low liveness)
# 103     (Low instrumentalness, Low liveness)
# 104                   (Low instrumentalness)
#
#                                         consequents  antecedent support  \
# 0                                 (Low speechiness)            0.999875
# 1                                 (Low duration_ms)            0.993800
# 2                                    (Low liveness)            0.999875
# 3                                 (Low duration_ms)            0.942150
# 4                                 (Low speechiness)            0.942150
# ..                                              ...                 ...
# 100                   (High loudness, Low liveness)            0.765925
# 101                 (Low duration_ms, Low liveness)            0.747075
# 102         (Low duration_ms, Low instrumentalness)            0.869225
# 103                (Low duration_ms, High loudness)            0.718300
# 104  (Low duration_ms, High loudness, Low liveness)            0.766025
#
#      consequent support   support  confidence      lift
# 0              0.993800  0.993675    0.993799  0.999999
# 1              0.999875  0.993675    0.999874  0.999999
# 2              0.942150  0.942050    0.942168  1.000019
# 3              0.999875  0.942050    0.999894  1.000019
# 4              0.993800  0.936875    0.994401  1.000605
# ..                  ...       ...         ...       ...
# 100            0.869225  0.701150    0.915429  1.053155
# 101            0.942050  0.701150    0.938527  0.996260
# 102            0.765925  0.701150    0.806638  1.053155
# 103            0.924350  0.701150    0.976124  1.056011
# 104            0.869125  0.701150    0.915310  1.053139
#
# [105 rows x 7 columns]

# %% [markdown]
# ## Comparisons

# %% [markdown]
# ### Min-Max vs. Z-Score normalisation
#
# We can see that while both methods work, Z-Score normalisation gives rise to much less frequent patterns. This is likely due to the variation in the domain of the values, attribute to attribute, and the effect it has on what is classified as low or high. Because of this I think that Min-Max normalisation is more suitable for this dataset.

# %%
display('Min-Max', dfNorm(pm_all_data.copy(), 'm'), 'Z-Score', dfNorm(pm_all_data.copy(), 'z'))

print('Min-Max')
display(pMine(pm_all_data.copy(), 'm', 0.7))
print('Z-Score')
display(pMine(pm_all_data.copy(), 'z', 0.7))
# Out:
# 'Min-Max'
#        popularity  acousticness  danceability  duration_ms    energy  \
# 0       -0.218750     -0.495301      0.139465    -0.500000  0.441896
# 1       -0.177083     -0.487249      0.107081    -0.454810  0.390804
# 2       -0.208333     -0.496928      0.104922    -0.455365  0.255562
# 3       -0.145833     -0.474498      0.271157    -0.465454  0.200463
# 4       -0.166667     -0.495331      0.124352    -0.453966  0.087260
# ...           ...           ...           ...          ...       ...
# 50000    0.114583     -0.466466      0.421200    -0.500000  0.074237
# 50001    0.250000     -0.342369      0.200993    -0.447861 -0.138144
# 50002    0.031250     -0.494006      0.183722    -0.460774  0.263576
# 50003    0.177083     -0.416566      0.279793    -0.445602 -0.027946
# 50004    0.197917     -0.397590      0.366149    -0.444672  0.142359
#
#        instrumentalness  liveness  loudness  mode  speechiness   valence
# 0              0.295181 -0.393642  0.323883  -0.5    -0.442916  0.265121
# 1              0.453815 -0.384554  0.287616  -0.5    -0.491628  0.035282
# 2             -0.488153  0.029450  0.335381   0.5    -0.486735 -0.164315
# 3             -0.497460 -0.351231  0.337724   0.5    -0.264380 -0.227823
# 4              0.412651 -0.351231  0.302914   0.5    -0.479341 -0.174395
# ...                 ...       ...       ...   ...          ...       ...
# 50000         -0.500000 -0.389602  0.288029   0.5    -0.200228 -0.167339
# 50001         -0.500000 -0.399700  0.233058   0.5    -0.464445 -0.386089
# 50002         -0.500000 -0.365368  0.319118   0.5    -0.365500 -0.101815
# 50003         -0.500000 -0.402729  0.327525  -0.5    -0.476297 -0.143145
# 50004         -0.500000 -0.235108  0.157492  -0.5    -0.414429  0.271169
#
# [40000 rows x 11 columns]
# 'Z-Score'
#        popularity  acousticness  danceability  duration_ms    energy  \
# 0       -0.930057     -0.942231      0.609281    -1.652803  1.304673
# 1       -0.672340     -0.919777      0.441458    -0.054252  1.120651
# 2       -0.865627     -0.946766      0.430270    -0.073878  0.633536
# 3       -0.479052     -0.884220      1.291761    -0.430782  0.435081
# 4       -0.607911     -0.942315      0.530964    -0.024404  0.027348
# ...           ...           ...           ...          ...       ...
# 50000    1.131678     -0.861823      2.069342    -1.652803 -0.019560
# 50001    1.969258     -0.515776      0.928145     0.191556 -0.784512
# 50002    0.616244     -0.938619      0.838639    -0.265226  0.662402
# 50003    1.518253     -0.722676      1.336514     0.271471 -0.387603
# 50004    1.647112     -0.669761      1.784043     0.304381  0.225802
#
#        instrumentalness  liveness  loudness      mode  speechiness   valence
# 0              1.648396 -0.476741  0.690479 -1.375502    -0.084666  1.184586
# 1              2.102344 -0.421715  0.412047 -1.375502    -0.574569  0.288730
# 2             -0.593186  2.084991  0.778755  0.726989    -0.525360 -0.489250
# 3             -0.619820 -0.219956  0.796743  0.726989     1.710918 -0.736789
# 4              1.984548 -0.219956  0.529497  0.726989    -0.451000 -0.528542
# ...                 ...       ...       ...       ...          ...       ...
# 50000         -0.627089 -0.452285  0.415221  0.726989     2.356103 -0.501037
# 50001         -0.627089 -0.513424 -0.006810  0.726989    -0.301186 -1.353672
# 50002         -0.627089 -0.305551  0.653899  0.726989     0.693931 -0.245640
# 50003         -0.627089 -0.531766  0.718443 -1.375502    -0.420381 -0.406737
# 50004         -0.627089  0.483145 -0.586953 -1.375502     0.201840  1.208161
#
# [40000 rows x 11 columns]
# Min-Max
#        Low popularity  High popularity  Low acousticness  High acousticness  \
# 0                True            False              True              False
# 1                True            False              True              False
# 2                True            False              True              False
# 3                True            False              True              False
# 4                True            False              True              False
# ...               ...              ...               ...                ...
# 50000           False             True              True              False
# 50001           False             True              True              False
# 50002           False             True              True              False
# 50003           False             True              True              False
# 50004           False             True              True              False
#
#        Low danceability  High danceability  Low duration_ms  High duration_ms  \
# 0                 False               True             True             False
# 1                 False               True             True             False
# 2                 False               True             True             False
# 3                 False               True             True             False
# 4                 False               True             True             False
# ...                 ...                ...              ...               ...
# 50000             False               True             True             False
# 50001             False               True             True             False
# 50002             False               True             True             False
# 50003             False               True             True             False
# 50004             False               True             True             False
#
#        Low energy  High energy  ...  Low liveness  High liveness  \
# 0           False         True  ...          True          False
# 1           False         True  ...          True          False
# 2           False         True  ...         False           True
# 3           False         True  ...          True          False
# 4           False         True  ...          True          False
# ...           ...          ...  ...           ...            ...
# 50000       False         True  ...          True          False
# 50001        True        False  ...          True          False
# 50002       False         True  ...          True          False
# 50003        True        False  ...          True          False
# 50004       False         True  ...          True          False
#
#        Low loudness  High loudness  Low mode  High mode  Low speechiness  \
# 0             False           True      True      False             True
# 1             False           True      True      False             True
# 2             False           True     False       True             True
# 3             False           True     False       True             True
# 4             False           True     False       True             True
# ...             ...            ...       ...        ...              ...
# 50000         False           True     False       True             True
# 50001         False           True     False       True             True
# 50002         False           True     False       True             True
# 50003         False           True      True      False             True
# 50004         False           True      True      False             True
#
#        High speechiness  Low valence  High valence
# 0                 False        False          True
# 1                 False        False          True
# 2                 False         True         False
# 3                 False         True         False
# 4                 False         True         False
# ...                 ...          ...           ...
# 50000             False         True         False
# 50001             False         True         False
# 50002             False         True         False
# 50003             False         True         False
# 50004             False        False          True
#
# [40000 rows x 22 columns]
#      support  \
# 0   0.999875
# 1   0.993800
# 2   0.942150
# 3   0.924450
# 4   0.766025
# 5   0.993675
# 6   0.942050
# 7   0.936875
# 8   0.936775
# 9   0.924350
# 10  0.918525
# 11  0.869225
# 12  0.918425
# 13  0.869125
# 14  0.864150
# 15  0.864050
# 16  0.765925
# 17  0.760025
# 18  0.747075
# 19  0.718300
# 20  0.759925
# 21  0.747000
# 22  0.741350
# 23  0.741275
# 24  0.718225
# 25  0.713225
# 26  0.701225
# 27  0.713150
# 28  0.701150
#
#                                                                    itemsets
# 0                                                         (Low duration_ms)
# 1                                                         (Low speechiness)
# 2                                                            (Low liveness)
# 3                                                           (High loudness)
# 4                                                    (Low instrumentalness)
# 5                                        (Low duration_ms, Low speechiness)
# 6                                           (Low duration_ms, Low liveness)
# 7                                           (Low liveness, Low speechiness)
# 8                          (Low duration_ms, Low liveness, Low speechiness)
# 9                                          (Low duration_ms, High loudness)
# 10                                         (High loudness, Low speechiness)
# 11                                            (High loudness, Low liveness)
# 12                        (Low duration_ms, High loudness, Low speechiness)
# 13                           (Low duration_ms, High loudness, Low liveness)
# 14                           (High loudness, Low liveness, Low speechiness)
# 15          (Low duration_ms, High loudness, Low liveness, Low speechiness)
# 16                                  (Low duration_ms, Low instrumentalness)
# 17                                  (Low instrumentalness, Low speechiness)
# 18                                    (High loudness, Low instrumentalness)
# 19                                     (Low instrumentalness, Low liveness)
# 20                 (Low duration_ms, Low instrumentalness, Low speechiness)
# 21                   (Low duration_ms, High loudness, Low instrumentalness)
# 22                   (High loudness, Low instrumentalness, Low speechiness)
# 23  (Low duration_ms, High loudness, Low instrumentalness, Low speechiness)
# 24                    (Low duration_ms, Low instrumentalness, Low liveness)
# 25                    (Low instrumentalness, Low liveness, Low speechiness)
# 26                      (High loudness, Low instrumentalness, Low liveness)
# 27   (Low duration_ms, Low instrumentalness, Low liveness, Low speechiness)
# 28     (Low duration_ms, High loudness, Low instrumentalness, Low liveness)
#                                  antecedents  \
# 0                          (Low duration_ms)
# 1                          (Low speechiness)
# 2                          (Low duration_ms)
# 3                             (Low liveness)
# 4                             (Low liveness)
# ..                                       ...
# 100  (Low duration_ms, Low instrumentalness)
# 101    (High loudness, Low instrumentalness)
# 102            (High loudness, Low liveness)
# 103     (Low instrumentalness, Low liveness)
# 104                   (Low instrumentalness)
#
#                                         consequents  antecedent support  \
# 0                                 (Low speechiness)            0.999875
# 1                                 (Low duration_ms)            0.993800
# 2                                    (Low liveness)            0.999875
# 3                                 (Low duration_ms)            0.942150
# 4                                 (Low speechiness)            0.942150
# ..                                              ...                 ...
# 100                   (High loudness, Low liveness)            0.765925
# 101                 (Low duration_ms, Low liveness)            0.747075
# 102         (Low duration_ms, Low instrumentalness)            0.869225
# 103                (Low duration_ms, High loudness)            0.718300
# 104  (Low duration_ms, High loudness, Low liveness)            0.766025
#
#      consequent support   support  confidence      lift
# 0              0.993800  0.993675    0.993799  0.999999
# 1              0.999875  0.993675    0.999874  0.999999
# 2              0.942150  0.942050    0.942168  1.000019
# 3              0.999875  0.942050    0.999894  1.000019
# 4              0.993800  0.936875    0.994401  1.000605
# ..                  ...       ...         ...       ...
# 100            0.869225  0.701150    0.915429  1.053155
# 101            0.942050  0.701150    0.938527  0.996260
# 102            0.765925  0.701150    0.806638  1.053155
# 103            0.924350  0.701150    0.976124  1.056011
# 104            0.869125  0.701150    0.915310  1.053139
#
# [105 rows x 7 columns]
# None
# Z-Score
#        Low popularity  High popularity  Low acousticness  High acousticness  \
# 0                True            False              True              False
# 1                True            False              True              False
# 2                True            False              True              False
# 3                True            False              True              False
# 4                True            False              True              False
# ...               ...              ...               ...                ...
# 50000           False             True              True              False
# 50001           False             True              True              False
# 50002           False             True              True              False
# 50003           False             True              True              False
# 50004           False             True              True              False
#
#        Low danceability  High danceability  Low duration_ms  High duration_ms  \
# 0                 False               True             True             False
# 1                 False               True             True             False
# 2                 False               True             True             False
# 3                 False               True             True             False
# 4                 False               True             True             False
# ...                 ...                ...              ...               ...
# 50000             False               True             True             False
# 50001             False               True            False              True
# 50002             False               True             True             False
# 50003             False               True            False              True
# 50004             False               True            False              True
#
#        Low energy  High energy  ...  Low liveness  High liveness  \
# 0           False         True  ...          True          False
# 1           False         True  ...          True          False
# 2           False         True  ...         False           True
# 3           False         True  ...          True          False
# 4           False         True  ...          True          False
# ...           ...          ...  ...           ...            ...
# 50000        True        False  ...          True          False
# 50001        True        False  ...          True          False
# 50002       False         True  ...          True          False
# 50003        True        False  ...          True          False
# 50004       False         True  ...         False           True
#
#        Low loudness  High loudness  Low mode  High mode  Low speechiness  \
# 0             False           True      True      False             True
# 1             False           True      True      False             True
# 2             False           True     False       True             True
# 3             False           True     False       True            False
# 4             False           True     False       True             True
# ...             ...            ...       ...        ...              ...
# 50000         False           True     False       True            False
# 50001          True          False     False       True             True
# 50002         False           True     False       True            False
# 50003         False           True      True      False             True
# 50004          True          False      True      False            False
#
#        High speechiness  Low valence  High valence
# 0                 False        False          True
# 1                 False        False          True
# 2                 False         True         False
# 3                  True         True         False
# 4                 False         True         False
# ...                 ...          ...           ...
# 50000              True         True         False
# 50001             False         True         False
# 50002              True         True         False
# 50003             False         True         False
# 50004              True        False          True
#
# [40000 rows x 22 columns]
#     support                itemsets
# 0  0.760325       (Low speechiness)
# 1  0.718075  (Low instrumentalness)
# Empty DataFrame
# Columns: [antecedents, consequents, antecedent support, consequent support, support, confidence, lift]
# Index: []
# None

# %% [markdown]
# ### Apriori vs. FP-Growth
#
# Much of this section taken from reference [Github repo](https://github.com/mustafahakkoz/Classification_Clustering_Freq_Pattern_Mining/blob/main/3.frequent-pattern-miningv2.ipynb) provided on course website (repo by mustafahakkoz)

# %% [markdown]
# #### Function to calulate the memory used to excecute an algorithm

# %%
def calculate_mem_use(snapshot, key_type='lineno', func=""):
    snapshot = snapshot.filter_traces((
        tracemalloc.Filter(False, "<frozen importlib._bootstrap>"),
        tracemalloc.Filter(False, "<unknown>"),
    ))
    top_stats = snapshot.statistics(key_type)
    total = 0
    for index, stat in enumerate(top_stats, 1):
        frame = stat.traceback[0]
        if func in frame.filename or "data" in frame.filename:
            total = total + stat.size
    return total

# %% [markdown]
# #### To display, memory used, time taken, and output for each algorithm
# We can see that while the output was the same from both algorithms, Aprior was more efficient in terms of time and memory usage. It took 1,200B, and 1.18429660797ns less to complete the same task with Apriori, compared to FP-Growth. In other words, FP-Growth took 7% more memory, and 3949% more time.

# %%
# normalise & discretise the data
ndf = dfNorm(pm_all_data.copy(), 'm')
ndf = stratifyData(ndf)

# Apriori
start = time.time()
tracemalloc.start()
ap = apriori(ndf, use_colnames=True, min_support=0.8)
snapshot = tracemalloc.take_snapshot()
done = time.time()
elapsed = done - start
mem_use = calculate_mem_use(snapshot, func="fpgrowth")
print("- APRIORI")
print("Mem. use : %1.f B" %(mem_use))
print("Elapsed Time : ",elapsed," ns")
display(ap)

# FP-Growth
start = time.time()
tracemalloc.start()
fp = fpgrowth(ndf, use_colnames=True, min_support=0.8)
snapshot = tracemalloc.take_snapshot()
done = time.time()
elapsed = done - start
mem_use = calculate_mem_use(snapshot, func="fpgrowth")
print("- FP-GROWTH")
print("Mem. use : %1.f B" %(mem_use))
print("Elapsed Time : ",elapsed," ns")
display(fp)
# Out:
# - APRIORI
# Mem. use : 16626 B
# Elapsed Time :  0.029993534088134766  ns
#      support                                                         itemsets
# 0   0.999875                                                (Low duration_ms)
# 1   0.942150                                                   (Low liveness)
# 2   0.924450                                                  (High loudness)
# 3   0.993800                                                (Low speechiness)
# 4   0.942050                                  (Low duration_ms, Low liveness)
# 5   0.924350                                 (Low duration_ms, High loudness)
# 6   0.993675                               (Low duration_ms, Low speechiness)
# 7   0.869225                                    (High loudness, Low liveness)
# 8   0.936875                                  (Low liveness, Low speechiness)
# 9   0.918525                                 (High loudness, Low speechiness)
# 10  0.869125                   (Low duration_ms, High loudness, Low liveness)
# 11  0.936775                 (Low duration_ms, Low liveness, Low speechiness)
# 12  0.918425                (Low duration_ms, High loudness, Low speechiness)
# 13  0.864150                   (High loudness, Low liveness, Low speechiness)
# 14  0.864050  (Low duration_ms, High loudness, Low liveness, Low speechiness)
# - FP-GROWTH
# Mem. use : 17826 B
# Elapsed Time :  1.2142901420593262  ns
#      support                                                         itemsets
# 0   0.999875                                                (Low duration_ms)
# 1   0.993800                                                (Low speechiness)
# 2   0.942150                                                   (Low liveness)
# 3   0.924450                                                  (High loudness)
# 4   0.993675                               (Low duration_ms, Low speechiness)
# 5   0.942050                                  (Low duration_ms, Low liveness)
# 6   0.936875                                  (Low liveness, Low speechiness)
# 7   0.936775                 (Low duration_ms, Low liveness, Low speechiness)
# 8   0.924350                                 (Low duration_ms, High loudness)
# 9   0.918525                                 (High loudness, Low speechiness)
# 10  0.869225                                    (High loudness, Low liveness)
# 11  0.918425                (Low duration_ms, High loudness, Low speechiness)
# 12  0.869125                   (Low duration_ms, High loudness, Low liveness)
# 13  0.864150                   (High loudness, Low liveness, Low speechiness)
# 14  0.864050  (Low duration_ms, High loudness, Low liveness, Low speechiness)
